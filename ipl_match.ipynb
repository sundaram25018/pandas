# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df.head()
# Out:
#        id        city       date player_of_match
# 0  335982   Bangalore  4/18/2008     BB McCullum  \
# 1  335983  Chandigarh  4/19/2008      MEK Hussey
# 2  335984       Delhi  4/19/2008     MF Maharoof
# 3  335985      Mumbai  4/20/2008      MV Boucher
# 4  335986     Kolkata  4/20/2008       DJ Hussey
#
#                                         venue  neutral_venue
# 0                       M Chinnaswamy Stadium              0  \
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2
# 0  Royal Challengers Bangalore        Kolkata Knight Riders  \
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.drop(['method'], axis=1)
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore   4/18/2008     BB McCullum  \
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.dropna()
# Out:
#           id           city       date   player_of_match
# 40    336022          Delhi  5/17/2008  DPMD Jayawardene  \
# 43    336025        Kolkata  5/18/2008           M Ntini
# 60    392183      Cape Town  4/19/2009        DL Vettori
# 63    392186         Durban  4/21/2009          CH Gayle
# 89    392214      Centurion   5/7/2009         ML Hayden
# 192   501215          Kochi  4/18/2011       BB McCullum
# 221   501245        Kolkata   5/7/2011     Iqbal Abdulla
# 231   501255      Bangalore  5/14/2011          CH Gayle
# 429   733993          Delhi  5/10/2014          DW Steyn
# 477   829743  Visakhapatnam  4/22/2015         DA Warner
# 508   829807      Hyderabad  5/15/2015           V Kohli
# 538   980943      Hyderabad  4/26/2016          AB Dinda
# 561   980989        Kolkata  5/14/2016         YK Pathan
# 565   980997  Visakhapatnam  5/17/2016          AB Dinda
# 566   980999      Bangalore  5/18/2016           V Kohli
# ...

# %%
df.head()
# Out:
#        id        city       date player_of_match
# 0  335982   Bangalore  4/18/2008     BB McCullum  \
# 1  335983  Chandigarh  4/19/2008      MEK Hussey
# 2  335984       Delhi  4/19/2008     MF Maharoof
# 3  335985      Mumbai  4/20/2008      MV Boucher
# 4  335986     Kolkata  4/20/2008       DJ Hussey
#
#                                         venue  neutral_venue
# 0                       M Chinnaswamy Stadium              0  \
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2
# 0  Royal Challengers Bangalore        Kolkata Knight Riders  \
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore   4/18/2008     BB McCullum  \
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
len(df)
# Out:
# 816

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.dtypes['result_margin']
# Out:
# dtype('float64')

# %%
df.replace(to_replace=np.nan, value=0)
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore   4/18/2008     BB McCullum  \
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop(["method"], axis=1, inplace=True)

# %%
df
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore   4/18/2008     BB McCullum  \
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
# most win in ipl
temp = pd.DataFrame({"winner":df['winner']})
count_win = temp.value_counts().max()
print(count_win)
# Out:
# 120

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
ax = sns.countplot(x = 'winner',data = df)
sns.set(rc={'figure.figsize':(20,3)})
plt.xticks(rotation = 90)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Delhi Capitals                  20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
ans = df['eliminator']=='Y'
df[ans]['winner'].value_counts()
# Out:
# winner
# Kings XI Punjab                3
# Rajasthan Royals               2
# Royal Challengers Bangalore    2
# Mumbai Indians                 2
# Delhi Capitals                 2
# Sunrisers Hyderabad            1
# Kolkata Knight Riders          1
# Name: count, dtype: int64

# %%
ax = sns.countplot(x = df['winner'][df['eliminator']=='Y'],data =df)
sns.set(rc={'figure.figsize':(20,3)})
plt.xticks(rotation = 90)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# SK Raina          14
# V Kohli           13
# G Gambhir         13
# Name: count, dtype: int64

# %%
df
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore   4/18/2008     BB McCullum  \
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['city'].value_counts().head(10)
# Out:
# city
# Mumbai        101
# Kolkata        77
# Delhi          74
# Bangalore      65
# Hyderabad      64
# Chennai        57
# Chandigarh     56
# Jaipur         47
# Pune           38
# Abu Dhabi      29
# Name: count, dtype: int64

# %%
run = df['result_margin'].max()

# %%
a = df['result_margin']==run

# %%
df[a]
# Out:
#           id   city      date player_of_match             venue
# 620  1082635  Delhi  5/6/2017     LMP Simmons  Feroz Shah Kotla  \
#
#      neutral_venue             team1           team2       toss_winner
# 620              0  Delhi Daredevils  Mumbai Indians  Delhi Daredevils  \
#
#     toss_decision          winner result  result_margin eliminator
# 620         field  Mumbai Indians   runs          146.0          N  \
#
#          umpire1    umpire2
# 620  Nitin Menon  CK Nandan

# %%
a = ((df['team1']=='Royal Challengers Bangalore') & (df['team2']=='Kolkata Knight Riders') )| ((df['team1']=='Kolkata Knight Riders') & (df['team2']=='Royal Challengers Bangalore') )

# %%
len(df[a])
# Out:
# 26

# %%
df[a]['winner']=='Kolkata Knight Riders'
# Out:
# 0       True
# 28      True
# 74     False
# 96     False
# 118     True
# 157    False
# 198    False
# 231    False
# 257     True
# 284     True
# 332    False
# 381     True
# 408     True
# 446     True
# 462    False
# 490    False
# 546     True
# 564    False
# 603     True
# 621     True
# 638     True
# 664     True
# 712     True
# 730    False
# 758    False
# 804    False
# Name: winner, dtype: bool
