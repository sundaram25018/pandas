# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mlt

# %%
df = pd.read_csv("movie.csv")

# %%
df
# Out:
#     Unnamed: 0  Rank  Peak                                          Title
# 0            0     1     1                                         Avatar  \
# 1            1     2     1                              Avengers: Endgame
# 2            2     3     3                       Avatar: The Way of Water
# 3            3     4     1                                        Titanic
# 4            4     5     3                   Star Wars: The Force Awakens
# 5            5     6     4                         Avengers: Infinity War
# 6            6     7     6                        Spider-Man: No Way Home
# 7            7     8     3                                 Jurassic World
# 8            8     9     7                                  The Lion King
# 9            9    10     3                                   The Avengers
# 10          10    11     4                                      Furious 7
# 11          11    12    11                              Top Gun: Maverick
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Rank             50 non-null     int64
#  2   Peak             50 non-null     object
#  3   Title            50 non-null     object
#  4   Worldwide gross  50 non-null     object
#  5   Year             50 non-null     int64
#  6   Reference(s)     50 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 2.9+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0      Rank         Year
# count    50.00000  50.00000    50.000000
# mean     24.50000  25.50000  2014.100000
# std      14.57738  14.57738     6.437296
# min       0.00000   1.00000  1993.000000
# 25%      12.25000  13.25000  2012.000000
# 50%      24.50000  25.50000  2016.000000
# 75%      36.75000  37.75000  2018.750000
# max      49.00000  50.00000  2023.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Rank               0
# Peak               0
# Title              0
# Worldwide gross    0
# Year               0
# Reference(s)       0
# dtype: int64

# %%
df = df.drop(["Reference(s)"], axis=1)

# %%
df
# Out:
#     Unnamed: 0  Rank  Peak                                          Title
# 0            0     1     1                                         Avatar  \
# 1            1     2     1                              Avengers: Endgame
# 2            2     3     3                       Avatar: The Way of Water
# 3            3     4     1                                        Titanic
# 4            4     5     3                   Star Wars: The Force Awakens
# 5            5     6     4                         Avengers: Infinity War
# 6            6     7     6                        Spider-Man: No Way Home
# 7            7     8     3                                 Jurassic World
# 8            8     9     7                                  The Lion King
# 9            9    10     3                                   The Avengers
# 10          10    11     4                                      Furious 7
# 11          11    12    11                              Top Gun: Maverick
# ...

# %%
df["Year"].value_counts()
# Out:
# Year
# 2019    9
# 2015    5
# 2018    5
# 2017    4
# 2012    4
# 2016    4
# 2011    3
# 2022    2
# 2013    2
# 2010    2
# 2014    1
# 1999    1
# 1993    1
# 2006    1
# 2009    1
# 2003    1
# 2023    1
# 2021    1
# 1997    1
# 2001    1
# Name: count, dtype: int64

# %%
ans = df["Year"]==2012

# %%
df[ans]
# Out:
#     Unnamed: 0  Rank Peak                              Title  Worldwide gross
# 9            9    10    3                       The Avengers  $1,518,815,515   \
# 31          31    32    7                            Skyfall  $1,108,569,499
# 33          33    34    7              The Dark Knight Rises  $1,081,169,825
# 48          48    49   14  The Hobbit: An Unexpected Journey  $1,017,030,651
#
#     Year
# 9   2012
# 31  2012
# 33  2012
# 48  2012

# %%
an = df['Title']=="The Lion King"

# %%
df[an]['Peak']
# Out:
# 8    7
# Name: Peak, dtype: object

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#     Rank  Peak                                          Title
# 0      1     1                                         Avatar  \
# 1      2     1                              Avengers: Endgame
# 2      3     3                       Avatar: The Way of Water
# 3      4     1                                        Titanic
# 4      5     3                   Star Wars: The Force Awakens
# 5      6     4                         Avengers: Infinity War
# 6      7     6                        Spider-Man: No Way Home
# 7      8     3                                 Jurassic World
# 8      9     7                                  The Lion King
# 9     10     3                                   The Avengers
# 10    11     4                                      Furious 7
# 11    12    11                              Top Gun: Maverick
# 12    13    10                                      Frozen II
# 13    14     5                        Avengers: Age of Ultron
# ...

# %%
# p1 =df[df['Title'].str.contains('Avengers', case=False)]
p1 =df[df['Title'].str.contains('Harry Potter', case=False)]

# %%
p1
# Out:
#     Rank Peak                                          Title
# 16    17    3  Harry Potter and the Deathly Hallows – Part 2  \
# 49    50    2       Harry Potter and the Philosopher's Stone
#
#       Worldwide gross  Year
# 16    $1,342,139,727   2011
# 49  HP1$1,009,046,830  2001

# %%
a1 = df['Peak']=='1'

# %%
df[a1]
# Out:
#     Rank Peak              Title  Worldwide gross  Year
# 0      1    1             Avatar  $2,923,706,026   2009
# 1      2    1  Avengers: Endgame  $2,797,501,328   2019
# 3      4    1            Titanic  T$2,257,844,554  1997
# 43    44    1      Jurassic Park  $1,034,199,003   1993

# %%
a2 = df['Year'] >= 2018

# %%
df[a2]
# Out:
#     Rank  Peak                             Title  Worldwide gross  Year
# 1      2     1                 Avengers: Endgame  $2,797,501,328   2019
# 2      3     3          Avatar: The Way of Water  $2,320,250,281   2022
# 5      6     4            Avengers: Infinity War  $2,048,359,754   2018
# 6      7     6           Spider-Man: No Way Home  $1,921,847,111   2021
# 8      9     7                     The Lion King  $1,656,943,394   2019
# 11    12    11                 Top Gun: Maverick  $1,495,696,292   2022
# 12    13    10                         Frozen II  $1,450,026,933   2019
# 14    15    15     The Super Mario Bros. Movie †  $1,355,281,519   2023
# 15    16     9                     Black Panther  $1,347,280,838   2018
# 18    19    12    Jurassic World: Fallen Kingdom  $1,308,473,425   2018
# 21    22    15                     Incredibles 2  $1,242,805,359   2018
# 26    27    20                           Aquaman  $1,148,528,393   2018
# ...

# %%
a3 = df["Title"]=="Captain Marvel"

# %%
df[a3]['Worldwide gross']
# Out:
# 29    $1,128,274,794
# Name: Worldwide gross, dtype: object
