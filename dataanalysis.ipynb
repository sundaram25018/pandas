# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns
import xlwings as xw

# %%
df = pd.read_csv('Book21.csv')

# %%
df.head()
# Out:
#    Customer_ID First_Name   Last_Name  Full_Name  Region  Country
# 0        12347      Karen       Parks        NaN  Europe  Iceland
# 1        12348       Myah        Mays        NaN  Europe  Finland
# 2        12350    Kaleigh  Valenzuela        NaN  Europe   Norway
# 3        12352      Aydin       Patel        NaN  Europe   Norway
# 4        12354      Hamza       Hobbs        NaN  Europe    Spain

# %%
df.drop('Full_Name', axis=1)
# Out:
#       Customer_ID First_Name   Last_Name  Region         Country
# 0           12347      Karen       Parks  Europe         Iceland
# 1           12348       Myah        Mays  Europe         Finland
# 2           12350    Kaleigh  Valenzuela  Europe          Norway
# 3           12352      Aydin       Patel  Europe          Norway
# 4           12354      Hamza       Hobbs  Europe           Spain
# ...           ...        ...         ...     ...             ...
# 2124        18270   Kayleigh     Salazar  Europe  United Kingdom
# 2125        18272     Cooper      Stokes  Europe  United Kingdom
# 2126        18273       Cade    Hatfield  Europe  United Kingdom
# 2127        18280      Jesse  Fitzgerald  Europe  United Kingdom
# 2128        18283     Hannah        Lutz  Europe  United Kingdom
#
# [2129 rows x 5 columns]

# %%
df.head()
# Out:
#    Customer_ID First_Name   Last_Name  Full_Name  Region  Country
# 0        12347      Karen       Parks        NaN  Europe  Iceland
# 1        12348       Myah        Mays        NaN  Europe  Finland
# 2        12350    Kaleigh  Valenzuela        NaN  Europe   Norway
# 3        12352      Aydin       Patel        NaN  Europe   Norway
# 4        12354      Hamza       Hobbs        NaN  Europe    Spain

# %%
df.drop('Full_Name', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Customer_ID First_Name   Last_Name  Region  Country
# 0        12347      Karen       Parks  Europe  Iceland
# 1        12348       Myah        Mays  Europe  Finland
# 2        12350    Kaleigh  Valenzuela  Europe   Norway
# 3        12352      Aydin       Patel  Europe   Norway
# 4        12354      Hamza       Hobbs  Europe    Spain

# %%
pd.isnull(df).sum()
# Out:
# Customer_ID    0
# First_Name     0
# Last_Name      0
# Region         0
# Country        0
# dtype: int64

# %%
df.describe()
# Out:
#         Customer_ID
# count   2129.000000
# mean   15272.922969
# std     1722.552625
# min    12347.000000
# 25%    13784.000000
# 50%    15228.000000
# 75%    16765.000000
# max    18283.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_ID  2129 non-null   int64
#  1   First_Name   2129 non-null   object
#  2   Last_Name    2129 non-null   object
#  3   Region       2129 non-null   object
#  4   Country      2129 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 83.3+ KB

# %%
option = ['United Kingdom']
result = df.loc[df['Country'].isin(option)]

# %%
result
# Out:
#       Customer_ID First_Name   Last_Name  Region         Country
# 161         12747      Laila      Bender  Europe  United Kingdom
# 162         12748   Mckinley       Olsen  Europe  United Kingdom
# 181         12820      Sasha     Salinas  Europe  United Kingdom
# 182         12823        Ace      Watson  Europe  United Kingdom
# 183         12826    Jazlynn      Thomas  Europe  United Kingdom
# ...           ...        ...         ...     ...             ...
# 2124        18270   Kayleigh     Salazar  Europe  United Kingdom
# 2125        18272     Cooper      Stokes  Europe  United Kingdom
# 2126        18273       Cade    Hatfield  Europe  United Kingdom
# 2127        18280      Jesse  Fitzgerald  Europe  United Kingdom
# 2128        18283     Hannah        Lutz  Europe  United Kingdom
#
# [1927 rows x 5 columns]

# %%
df
# Out:
#       Customer_ID First_Name   Last_Name  Region         Country
# 0           12347      Karen       Parks  Europe         Iceland
# 1           12348       Myah        Mays  Europe         Finland
# 2           12350    Kaleigh  Valenzuela  Europe          Norway
# 3           12352      Aydin       Patel  Europe          Norway
# 4           12354      Hamza       Hobbs  Europe           Spain
# ...           ...        ...         ...     ...             ...
# 2124        18270   Kayleigh     Salazar  Europe  United Kingdom
# 2125        18272     Cooper      Stokes  Europe  United Kingdom
# 2126        18273       Cade    Hatfield  Europe  United Kingdom
# 2127        18280      Jesse  Fitzgerald  Europe  United Kingdom
# 2128        18283     Hannah        Lutz  Europe  United Kingdom
#
# [2129 rows x 5 columns]

# %%
cust = df.loc[df['Customer_ID']<13000]

# %%
cust
# Out:
#      Customer_ID First_Name   Last_Name  Region         Country
# 0          12347      Karen       Parks  Europe         Iceland
# 1          12348       Myah        Mays  Europe         Finland
# 2          12350    Kaleigh  Valenzuela  Europe          Norway
# 3          12352      Aydin       Patel  Europe          Norway
# 4          12354      Hamza       Hobbs  Europe           Spain
# ..           ...        ...         ...     ...             ...
# 240        12990      Itzel      Daniel  Europe  United Kingdom
# 241        12993     Ashton      Ashley  Europe  United Kingdom
# 242        12994      Rishi     Rodgers  Europe  United Kingdom
# 243        12997      Mayra       Ortiz  Europe  United Kingdom
# 244        12999     Makena       Chang  Europe  United Kingdom
#
# [245 rows x 5 columns]

# %%
df = pd.read_csv('Book1.csv', index_col=False)

# %%
df
# Out:
#      omrrts  Customer_#  Order_Date   Product_#  Quantity  Unit_Price
# 0       101       10127   9/23/2015   Product 8        23         8.0  \
# 1       102       10041  11/10/2015   Product 1         6        18.0
# 2       103       10044   3/29/2010  Product 10        19        13.0
# 3       104       10125    6/2/2014   Product 6        29         4.0
# 4       105       10034  10/21/2011   Product 6        30         4.0
# ..      ...         ...         ...         ...       ...         ...
# 495     596       10075  10/19/2010   Product 8        30         8.0
# 496     597       10026   6/21/2013   Product 8        29         8.0
# 497     598       10137    5/9/2013   Product 9        20         2.0
# 498     599       10135  10/15/2012   Product 3         2        12.0
# 499     600       10131  11/17/2015   Product 7        29         9.0
#
#      Total_Cost Order_Category
# 0         184.0    Large Order
# 1         108.0   Normal Order
# ...

# %%
pd.isnull(df).sum()
# Out:
# omrrts            0
# Customer_#        0
# Order_Date        0
# Product_#         0
# Quantity          0
# Unit_Price        0
# Total_Cost        0
# Order_Category    0
# dtype: int64

# %%
ax = sns.countplot(x = 'Order_Category',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(x = 'Product_#',data = df)
sns.set(rc={'figure.figsize':(15,10)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_#'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False).head(10)

sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(data = sales_state, x = 'Product_#',y= 'Quantity')
# Out:
# <Axes: xlabel='Product_#', ylabel='Quantity'>

# %%
df['Product_#']
# Out:
# 0       Product 8
# 1       Product 1
# 2      Product 10
# 3       Product 6
# 4       Product 6
#           ...
# 495     Product 8
# 496     Product 8
# 497     Product 9
# 498     Product 3
# 499     Product 7
# Name: Product_#, Length: 500, dtype: object

# %%
df['Total_Cost'].dtype
# Out:
# dtype('float64')

# %%
d = df.index[df['Product_#']==8]

# %%
d
# Out:
# Index([], dtype='int64')

# %%
df.sort_values("Product_#")
# Out:
#      omrrts  Customer_# Order_Date  Product_#  Quantity  Unit_Price
# 180     281       10111  6/19/2012  Product 1        26        18.0  \
# 433     534       10031   8/1/2012  Product 1        16        18.0
# 174     275       10139   9/6/2015  Product 1        13        18.0
# 177     278       10043  9/27/2011  Product 1        15        18.0
# 178     279       10027  5/21/2012  Product 1        16        18.0
# ..      ...         ...        ...        ...       ...         ...
# 384     485       10092  7/19/2014  Product 9        11         2.0
# 58      159       10051  7/16/2011  Product 9        26         2.0
# 55      156       10047   9/7/2012  Product 9         7         2.0
# 382     483       10069  5/27/2014  Product 9        24         2.0
# 357     458       10065   5/1/2014  Product 9        12         2.0
#
#      Total_Cost Order_Category
# 180       468.0    Large Order
# 433       288.0    Large Order
# 174       234.0   Normal Order
# ...

# %%
d= df.values[df['Product_#']=='Product_8']

# %%
d
# Out:
# array([], shape=(0, 8), dtype=object)

# %%
total = df['Quantity'].sum()

# %%
total
# Out:
# 7712

# %%
data = df['Customer_#']<11111

# %%
data
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Customer_#, Length: 500, dtype: bool

# %%
df
# Out:
#      omrrts  Customer_#  Order_Date   Product_#  Quantity  Unit_Price
# 0       101       10127   9/23/2015   Product 8        23         8.0  \
# 1       102       10041  11/10/2015   Product 1         6        18.0
# 2       103       10044   3/29/2010  Product 10        19        13.0
# 3       104       10125    6/2/2014   Product 6        29         4.0
# 4       105       10034  10/21/2011   Product 6        30         4.0
# ..      ...         ...         ...         ...       ...         ...
# 495     596       10075  10/19/2010   Product 8        30         8.0
# 496     597       10026   6/21/2013   Product 8        29         8.0
# 497     598       10137    5/9/2013   Product 9        20         2.0
# 498     599       10135  10/15/2012   Product 3         2        12.0
# 499     600       10131  11/17/2015   Product 7        29         9.0
#
#      Total_Cost Order_Category
# 0         184.0    Large Order
# 1         108.0   Normal Order
# ...

# %%
a1 = df['Product_#']=='Product 6'

# %%
a2 = df['Order_Category']=='Normal Order'

# %%
df[a1 & a2]
# Out:
#      omrrts  Customer_#  Order_Date  Product_#  Quantity  Unit_Price
# 192     293       10048   4/11/2010  Product 6         6         4.0  \
# 272     373       10046    3/2/2014  Product 6        12         4.0
# 306     407       10107   12/7/2014  Product 6        11         4.0
# 341     442       10052  11/15/2015  Product 6        13         4.0
# 442     543       10080   1/14/2012  Product 6         8         4.0
#
#      Total_Cost Order_Category
# 192        24.0   Normal Order
# 272        48.0   Normal Order
# 306        44.0   Normal Order
# 341        52.0   Normal Order
# 442        32.0   Normal Order

# %%
df.rename(columns= {'omrrts':'id'})
# Out:
#       id  Customer_#  Order_Date   Product_#  Quantity  Unit_Price
# 0    101       10127   9/23/2015   Product 8        23         8.0  \
# 1    102       10041  11/10/2015   Product 1         6        18.0
# 2    103       10044   3/29/2010  Product 10        19        13.0
# 3    104       10125    6/2/2014   Product 6        29         4.0
# 4    105       10034  10/21/2011   Product 6        30         4.0
# ..   ...         ...         ...         ...       ...         ...
# 495  596       10075  10/19/2010   Product 8        30         8.0
# 496  597       10026   6/21/2013   Product 8        29         8.0
# 497  598       10137    5/9/2013   Product 9        20         2.0
# 498  599       10135  10/15/2012   Product 3         2        12.0
# 499  600       10131  11/17/2015   Product 7        29         9.0
#
#      Total_Cost Order_Category
# 0         184.0    Large Order
# 1         108.0   Normal Order
# 2         247.0    Large Order
# 3         116.0    Large Order
# ...

# %%
df.describe()
# Out:
#            omrrts   Customer_#    Quantity  Unit_Price  Total_Cost
# count  500.000000    500.00000  500.000000   500.00000  500.000000
# mean   350.500000  10077.12600   15.424000     9.34400  142.088000
# std    144.481833     42.40777    8.779658     5.06171  120.192532
# min    101.000000  10001.00000    1.000000     2.00000    2.000000
# 25%    225.750000  10040.00000    7.000000     4.00000   43.500000
# 50%    350.500000  10077.00000   16.000000    12.00000  108.000000
# 75%    475.250000  10113.00000   23.000000    12.00000  218.000000
# max    600.000000  10150.00000   30.000000    18.00000  540.000000

# %%
a1 = df['Quantity']>20

# %%
df[a1]
# Out:
#      omrrts  Customer_#  Order_Date  Product_#  Quantity  Unit_Price
# 0       101       10127   9/23/2015  Product 8        23         8.0  \
# 3       104       10125    6/2/2014  Product 6        29         4.0
# 4       105       10034  10/21/2011  Product 6        30         4.0
# 5       106       10054   8/24/2013  Product 5        30        12.0
# 6       107       10075    3/2/2012  Product 3        24        12.0
# ..      ...         ...         ...        ...       ...         ...
# 493     594       10003   10/8/2011  Product 1        29        18.0
# 494     595       10111    7/3/2013  Product 2        29        12.0
# 495     596       10075  10/19/2010  Product 8        30         8.0
# 496     597       10026   6/21/2013  Product 8        29         8.0
# 499     600       10131  11/17/2015  Product 7        29         9.0
#
#      Total_Cost Order_Category
# 0         184.0    Large Order
# 3         116.0    Large Order
# 4         120.0    Large Order
# ...

# %%
a2 = df['Product_#']=='Product 6'

# %%
df[a1 & a2]
# Out:
#      omrrts  Customer_#  Order_Date  Product_#  Quantity  Unit_Price
# 3       104       10125    6/2/2014  Product 6        29         4.0  \
# 4       105       10034  10/21/2011  Product 6        30         4.0
# 25      126       10102    5/1/2013  Product 6        28         4.0
# 105     206       10065   9/20/2012  Product 6        28         4.0
# 150     251       10137   8/20/2012  Product 6        29         4.0
# 158     259       10003   4/23/2013  Product 6        24         4.0
# 175     276       10042  12/23/2012  Product 6        30         4.0
# 214     315       10148   4/24/2014  Product 6        23         4.0
# 227     328       10097  10/17/2010  Product 6        23         4.0
# 235     336       10074   1/21/2014  Product 6        21         4.0
# 263     364       10111    7/9/2013  Product 6        27         4.0
# 265     366       10007  12/25/2011  Product 6        28         4.0
# 275     376       10148   9/18/2015  Product 6        21         4.0
# ...

# %%
sales_state = df.groupby(['Product_#'], as_index=False)['Unit_Price'].sum().sort_values(by='Unit_Price', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'Product_#',y= 'Unit_Price')
# Out:
# <Axes: xlabel='Product_#', ylabel='Unit_Price'>

# %%
sales_state = df.groupby(['Product_#'], as_index=False)['Total_Cost'].sum().sort_values(by='Total_Cost', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'Product_#',y= 'Total_Cost')
# Out:
# <Axes: xlabel='Product_#', ylabel='Total_Cost'>

# %%
a1 = df['Product_#']=='Product 3'

# %%
df.rename(columns= {'omrrts':'id'}, inplace=True)

# %%
df
# Out:
#       id  Customer_#  Order_Date   Product_#  Quantity  Unit_Price
# 0    101       10127   9/23/2015   Product 8        23         8.0  \
# 1    102       10041  11/10/2015   Product 1         6        18.0
# 2    103       10044   3/29/2010  Product 10        19        13.0
# 3    104       10125    6/2/2014   Product 6        29         4.0
# 4    105       10034  10/21/2011   Product 6        30         4.0
# ..   ...         ...         ...         ...       ...         ...
# 495  596       10075  10/19/2010   Product 8        30         8.0
# 496  597       10026   6/21/2013   Product 8        29         8.0
# 497  598       10137    5/9/2013   Product 9        20         2.0
# 498  599       10135  10/15/2012   Product 3         2        12.0
# 499  600       10131  11/17/2015   Product 7        29         9.0
#
#      Total_Cost Order_Category
# 0         184.0    Large Order
# 1         108.0   Normal Order
# 2         247.0    Large Order
# 3         116.0    Large Order
# ...

# %%
df.head()
# Out:
#     id  Customer_#  Order_Date   Product_#  Quantity  Unit_Price  Total_Cost
# 0  101       10127   9/23/2015   Product 8        23         8.0       184.0  \
# 1  102       10041  11/10/2015   Product 1         6        18.0       108.0
# 2  103       10044   3/29/2010  Product 10        19        13.0       247.0
# 3  104       10125    6/2/2014   Product 6        29         4.0       116.0
# 4  105       10034  10/21/2011   Product 6        30         4.0       120.0
#
#   Order_Category
# 0    Large Order
# 1   Normal Order
# 2    Large Order
# 3    Large Order
# 4    Large Order

# %%
df.rename(columns={'Customer_#': 'Customer_id'}, inplace=True)

# %%
df
# Out:
#       id  Customer_id  Order_Date   Product_#  Quantity  Unit_Price
# 0    101        10127   9/23/2015   Product 8        23         8.0  \
# 1    102        10041  11/10/2015   Product 1         6        18.0
# 2    103        10044   3/29/2010  Product 10        19        13.0
# 3    104        10125    6/2/2014   Product 6        29         4.0
# 4    105        10034  10/21/2011   Product 6        30         4.0
# ..   ...          ...         ...         ...       ...         ...
# 495  596        10075  10/19/2010   Product 8        30         8.0
# 496  597        10026   6/21/2013   Product 8        29         8.0
# 497  598        10137    5/9/2013   Product 9        20         2.0
# 498  599        10135  10/15/2012   Product 3         2        12.0
# 499  600        10131  11/17/2015   Product 7        29         9.0
#
#      Total_Cost Order_Category
# 0         184.0    Large Order
# 1         108.0   Normal Order
# 2         247.0    Large Order
# ...
